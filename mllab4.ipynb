# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a53044/ml_lab/blob/main/mllab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Salary_dataset.csv')
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
x=df.YearsExperience
y=df.Salary
x
# Out:
# 0      1.2
# 1      1.4
# 2      1.6
# 3      2.1
# 4      2.3
# 5      3.0
# 6      3.1
# 7      3.3
# 8      3.3
# 9      3.8
# 10     4.0
# 11     4.1
# 12     4.1
# 13     4.2
# 14     4.6
# 15     5.0
# 16     5.2
# 17     5.4
# 18     6.0
# 19     6.1
# 20     6.9
# 21     7.2
# 22     8.0
# 23     8.3
# 24     8.8
# 25     9.1
# 26     9.6
# 27     9.7
# 28    10.4
# 29    10.6
# Name: YearsExperience, dtype: float64

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
import numpy as np
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

# %%
x
y
# Out:
# array([[ 39344.],
#        [ 46206.],
#        [ 37732.],
#        [ 43526.],
#        [ 39892.],
#        [ 56643.],
#        [ 60151.],
#        [ 54446.],
#        [ 64446.],
#        [ 57190.],
#        [ 63219.],
#        [ 55795.],
#        [ 56958.],
#        [ 57082.],
#        [ 61112.],
#        [ 67939.],
#        [ 66030.],
#        [ 83089.],
#        [ 81364.],
#        [ 93941.],
#        [ 91739.],
#        [ 98274.],
#        [101303.],
#        [113813.],
#        [109432.],
#        [105583.],
#        [116970.],
#        [112636.],
#        [122392.],
#        [121873.]])

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("Actual salary",y_test[:5])
print("Predicted salary",y_pred[:5])
# Out:
# Actual salary [[ 37732.]
#  [122392.]
#  [ 57082.]
#  [ 63219.]
#  [116970.]]
# Predicted salary [[ 39458.30599632]
#  [122387.880839  ]
#  [ 63960.2258362 ]
#  [ 62075.4627716 ]
#  [114848.82858057]]

# %%
#calculate mean squared error

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
print("Mean square error",mse)
# Out:
# Mean square error 10100169.82273963

# %%
#calculate rsme

# %%
from sklearn.metrics import root_mean_squared_error
import math

# %%
rmse=math.sqrt(mse)
print("Root mean square error",rmse)
# Out:
# Root mean square error 3178.07643437656

# %%
#calculate r^2 value

# %%
from sklearn.metrics import r2_score

# %%
R2=r2_score(y_test,y_pred)
print("R^2 value",R2)
# Out:
# R^2 value 0.9906818951583944

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color='blue')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(y_test,y_pred,label="actual salary")
plt.scatter(y_test,y_pred,label="predicted salary")
plt.xlabel("Actual salary")
plt.ylabel("Predicted salary")
plt.legend()
plt.show()

# %%
slope=model.coef_
intercept=model.intercept_
print("Slope",slope)
print("intercept:",intercept)
# Out:
# Slope [[9423.81532303]]
# intercept: [24380.20147947]

# %%
experience=[[5]]

# %%
predicted_salary=model.predict(experience)
print("Predicted salary for 5 years of experience",predicted_salary)
# Out:
# Predicted salary for 5 years of experience [[71499.27809463]]

# %%
experience=[[5]]

# %%
actualsalary=model.predict(experience)
print("Actual salary for 9 years of experience",actualsalary)
# Out:
# Actual salary for 9 years of experience [[71499.27809463]]

# %%
salary_manual=slope*5+intercept
print("salary using equation ",salary_manual)
# Out:
# salary using equation  [[71499.27809463]]
